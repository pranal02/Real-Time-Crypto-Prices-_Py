# %%
import json
import requests 
key = "https://api.binance.com/api/v3/ticker/price?symbol="
currencies  = [
    "BTCUSDT", "ETHUSDT", "BNBUSDT", "XRPUSDT", "DOGEUSDT", "LTCUSDT", "ADAUSDT", 
    "SOLUSDT", "DOTUSDT", "MATICUSDT", "SHIBUSDT", "TRXUSDT", "AVAXUSDT", "ATOMUSDT", 
    "LINKUSDT", "XLMUSDT", "NEARUSDT", "FTMUSDT", "VETUSDT", "ICPUSDT", "FILUSDT", 
    "SANDUSDT", "EGLDUSDT", "AXSUSDT", "GALAUSDT", "AAVEUSDT", "ALGOUSDT", "RUNEUSDT", 
    "MANAUSDT", "FTTUSDT", "CHZUSDT", "CAKEUSDT", "1INCHUSDT", "ZECUSDT", "THETAUSDT", 
    "KSMUSDT", "KAVAUSDT", "HBARUSDT", "BCHUSDT", "COMPUSDT", "LRCUSDT", "QTUMUSDT", 
    "OMGUSDT", "ZILUSDT", "ENJUSDT", "GRTUSDT", "SNXUSDT", "SUSHIUSDT", "XMRUSDT", 
    "WAVESUSDT", "YFIUSDT", "CRVUSDT", "RLCUSDT", "UNIUSDT", "BALUSDT", "RSRUSDT", 
    "LUNAUSDT", "STMXUSDT", "IOSTUSDT", "ANKRUSDT", "CELRUSDT", "HOTUSDT", "BATUSDT", 
    "ZENUSDT", "DGBUSDT", "SCUSDT", "STORJUSDT", "ICXUSDT", "ONTUSDT", "NANOUSDT", 
    "ARUSDT", "GNOUSDT", "KNCUSDT", "BNTUSDT", "OCEANUSDT", "HNTUSDT", "TWTUSDT", 
    "PERPUSDT", "SRMUSDT", "COTIUSDT", "MTLUSDT", "CTSIUSDT", "BELUSDT", "AKROUSDT", 
    "REEFUSDT", "BTSUSDT", "SLPUSDT", "LITUSDT", "TRBUSDT", "ALPHAUSDT", "WNXMUSDT", 
    "BAKEUSDT", "FLMUSDT", "MDTUSDT", "TVKUSDT", "UNFIUSDT", "SUNUSDT", "DENTUSDT", 
    "CHRUSDT", "HIVEUSDT", "CTKUSDT", "XEMUSDT", "PUNDIXUSDT", "DODOUSDT", "ALICEUSDT", 
    "TLMUSDT", "C98USDT", 
]
j = 0
for i in currencies: 
    
   
    url = key+currencies[j]   
    data = requests.get(url) 

    
    data = data.json() 
    j = j+1
    print(f"{data['symbol']} price is {data['price']}")
# Out:
# BTCUSDT price is 54336.94000000
# ETHUSDT price is 2284.93000000
# BNBUSDT price is 495.20000000
# XRPUSDT price is 0.52970000
# DOGEUSDT price is 0.09481000
# LTCUSDT price is 62.68000000
# ADAUSDT price is 0.32680000
# SOLUSDT price is 128.04000000
# DOTUSDT price is 4.10400000
# MATICUSDT price is 0.37320000
# SHIBUSDT price is 0.00001293
# TRXUSDT price is 0.15120000
# AVAXUSDT price is 21.80000000
# ATOMUSDT price is 3.69900000
# LINKUSDT price is 10.05000000
# XLMUSDT price is 0.08880000
# NEARUSDT price is 3.70700000
# FTMUSDT price is 0.38680000
# VETUSDT price is 0.02023000
# ICPUSDT price is 7.06000000
# FILUSDT price is 3.35700000
# SANDUSDT price is 0.24100000
# EGLDUSDT price is 24.73000000
# AXSUSDT price is 4.28300000
# GALAUSDT price is 0.01854000
# AAVEUSDT price is 127.23000000
# ALGOUSDT price is 0.12160000
# RUNEUSDT price is 3.55200000
# MANAUSDT price is 0.25640000
# FTTUSDT price is 1.25570000
# CHZUSDT price is 0.05050000
# CAKEUSDT price is 1.59900000
# ...
